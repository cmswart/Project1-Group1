# %%
#dependencies and setup
import matplotlib.pyplot as plt
import pandas as pd 
import scipy.stats as st
import numpy as np
import ipympl
from textwrap import wrap
#study data files
happiness_path = "happiness.csv"


#read the csv files
happiness_df = pd.read_csv(happiness_path)

#display data
happiness_df
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high
# 0                      Norway               1            7.537      7.594445  \
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %%
#Generate Bar Chart Top 5 Countries
Country = ["Norway, Denmark, Iceland, Switzerland, Finland"]
Happiness_Score = [7.537, 7.522, 7.504, 7.494, 7.469]
x_axis = np.arange(len(Happiness_Score))
tick_locations = [value for value in x_axis]
plt.bar(x_axis, Happiness_Score, color="blue", alpha=0.75, align="center")
plt.xticks(tick_locations, ['Norway', 'Denmark', 'Iceland', 'Switzerland', 'Finland'])
plt.xlim(-0.7, len(x_axis)-0.25)
plt.ylim(7.25,7.6)
plt.xlabel("Country")
plt.ylabel("Happiness Score")
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#Generate Bar Chart Bottom 5 Countries
Country = ["Rwanda, Syria, Tanzania, Burundi, Central Africa Republic"]
Happiness_Score = [3.471, 3.462, 3.349, 2.905, 2.693]
x_axis = np.arange(len(Happiness_Score))
tick_locations = [value for value in x_axis]
plt.bar(x_axis, Happiness_Score, color="blue", alpha=0.75, align="center")
plt.xticks(tick_locations, ['Rwanda', 'Syria', 'Tanzania', 'Burundi', 'Central Africa Republic'], rotation=45)
plt.xlim(-.7, len(x_axis)-.3)
plt.ylim(0,max(Happiness_Score)+1.5)
plt.xlabel("Country")
plt.ylabel("Happiness Score")
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
