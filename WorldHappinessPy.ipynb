# %%
# Dependencies and Set up
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# File (CSV)
data_file = "happiness.csv"
data_file = " un_data.csv"

# %%
# Load the CSV file into a Pandas DataFrame
un_data_df = pd.read_csv("un_data.csv")

# Display sample data
un_data_df
# Out:
#            country             Region  Surface area (km2)  \
# 0      Afghanistan       SouthernAsia              652864
# 1          Albania     SouthernEurope               28748
# 2          Armenia        WesternAsia               29743
# 3       Azerbaijan        WesternAsia               86600
# 4           Belize     CentralAmerica               22966
# ..             ...                ...                 ...
# 81         Vietnam  South-easternAsia              330967
# 82  Virgin Islands          Caribbean                 347
# 83           Yemen        WesternAsia              527968
# 84          Zambia      EasternAfrica              752612
# 85        Zimbabwe      EasternAfrica              390757
#
#     Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                            35530                                54.4
# 1                             2930                               106.9
# ...

# %%
# Load the CSV file into a Pandas DataFrame
happiness_data_df = pd.read_csv("happiness.csv")

# Display sample data
happiness_data_df
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %%
merged_df = un_data_df.merge(happiness_data_df, how= "inner", left_on="country", right_on="Country")
merged_df
# Out:
#           country             Region  Surface area (km2)  \
# 0     Afghanistan       SouthernAsia              652864
# 1         Albania     SouthernEurope               28748
# 2         Armenia        WesternAsia               29743
# 3      Azerbaijan        WesternAsia               86600
# 4          Belize     CentralAmerica               22966
# ..            ...                ...                 ...
# 66  United States    NorthernAmerica             9833517
# 67        Vietnam  South-easternAsia              330967
# 68          Yemen        WesternAsia              527968
# 69         Zambia      EasternAfrica              752612
# 70       Zimbabwe      EasternAfrica              390757
#
#     Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                            35530                                54.4
# 1                             2930                               106.9
# ...

# %%
corr = merged_df.corr()
corr[(corr['Happiness.Score'] > 0.5) | (corr['Happiness.Score'] < -0.5)]['Happiness.Score']
# Out:
# GDP per capita (current US$)                                  0.590946
# Economy: Agriculture (% of GVA)                              -0.522607
# Economy: Services and other activity (% of GVA)               0.574253
# Employment: Services (% of employed)                          0.596429
# Urban population (% of total population)                      0.672635
# Urban population growth rate (average annual %)              -0.554628
# Fertility rate, total (live births per woman)                -0.604339
# Infant mortality rate (per 1000 live births                  -0.631744
# Mobile-cellular subscriptions (per 100 inhabitants).1         0.682520
# Energy production, primary (Petajoules)                       0.500227
# Pop. using improved sanitation facilities (urban/rural, %)   -0.515240
# Happiness.Rank                                               -0.993493
# Happiness.Score                                               1.000000
# ...

# %%
# I noticed that there was a negative value (-99) replaced it with 0

merged_df["Employment: Services (% of employed)"].replace(-99, 0, inplace=True)

# %%
x = merged_df["Employment: Services (% of employed)"]
y = merged_df["Happiness.Score"]

(slope, intercept, r, p, stderr) = linregress(x, y)

print("Rvalue", r)
reg_line = (slope * x) + intercept
plt.scatter(x, y)
plt.xlabel('Employment: Services (% of employed)')
plt.ylabel('Happiness.Score')
plt.plot(x, reg_line,  color="r")
# Out:
# Rvalue 0.696517872638951
